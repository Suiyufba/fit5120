# %% [markdown]
# # HikeShield Route Intro Training
#
# This notebook fine-tunes a small Qwen model for route intro generation using the prepared HikeShield dataset.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content
# !pip install -U pip
# !pip install "torchao>=0.16.0"
# !pip install -r requirements.txt

# %%
# !python train_lora.py --config lora.qwen-0.5b.colab.json

# %%
# !python evaluate_model.py \
  --model /content/drive/MyDrive/hikeshield-route-intro/qwen2.5-0.5b-route-intro-lora \
  --eval-file route_intro_eval.combined.jsonl \
  --limit 3
